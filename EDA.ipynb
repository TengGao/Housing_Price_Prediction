# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd 
import numpy as np
# %matplotlib inline

pd.options.display.max_columns=9999
pd.options.display.max_rows=999
pd.options.display.float_format = '{:,.2f}'.format

from plotly.offline import iplot
import cufflinks as cf
import plotly_express as px
import seaborn as sns
cf.set_config_file(offline=True, theme='ggplot')
import missingno as mso
import matplotlib.pyplot as plt
#plt.style.use("dark_background")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import sparklines

def sparkline_str(x):
    bins=np.histogram(x)[0]
    sl = ''.join(sparklines(bins))
    return sl
sparkline_str.__name__ = "sparkline"

# %%
df = pd.read_csv('data/train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL        65.00     8450   Pave   NaN      Reg
# 1   2          20       RL        80.00     9600   Pave   NaN      Reg
# 2   3          60       RL        68.00    11250   Pave   NaN      IR1
# 3   4          70       RL        60.00     9550   Pave   NaN      IR1
# 4   5          60       RL        84.00    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
mso.matrix(df);

# %%
df.isna().sum().sort_values(ascending=False).iplot(kind='bar',title='Number of Missing Values per Columns')
# Out:
# <div>
#
#
#             <div id="f9710dee-4538-455a-ab11-57c0bf6cc5c6" class="plotly-graph-div"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f9710dee-4538-455a-ab11-57c0bf6cc5c6")) {
#                     Plotly.newPlot(
#                         'f9710dee-4538-455a-ab11-57c0bf6cc5c6',
# ...

# %%
from plotly import tools
import plotly.graph_objs as go 

fig = tools.make_subplots(rows=num_rows, cols=2, print_grid=False,
                          subplot_titles=(cat_features.columns))

for i, col in enumerate(cat_features.columns):
    count = df[col].value_counts()
    trace = go.Bar(x=count.index, y=count.values)
    fig.append_trace(trace, i//2+1, i%2+1)
fig['layout'].update(height=num_rows*500, width=1200, showlegend=False, template='plotly_dark', title='Value Counts Per Columns')
iplot(fig)
# Out:
# <div>
#
#
#             <div id="5bfc9501-1c96-4884-8876-3450837c515b" class="plotly-graph-div"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5bfc9501-1c96-4884-8876-3450837c515b")) {
#                     Plotly.newPlot(
#                         '5bfc9501-1c96-4884-8876-3450837c515b',
# ...

# %%
numeric_cols = [col for col in df.select_dtypes(include=['float64']).columns]

# %%
px.scatter_matrix(df, dimensions=numeric_cols, template='plotly_dark')
# Out:
# <div>
#
#
#             <div id="f54c2a85-91ae-429a-ad8a-1cc0fea78e73" class="plotly-graph-div"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f54c2a85-91ae-429a-ad8a-1cc0fea78e73")) {
#                     Plotly.newPlot(
#                         'f54c2a85-91ae-429a-ad8a-1cc0fea78e73',
# ...

# %%
histogram_grid(df.select_dtypes(include=['int64']))
# Out:
# <div>
#
#
#             <div id="4eb8641f-c4e4-4907-9f41-fd49a89583b7" class="plotly-graph-div"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4eb8641f-c4e4-4907-9f41-fd49a89583b7")) {
#                     Plotly.newPlot(
#                         '4eb8641f-c4e4-4907-9f41-fd49a89583b7',
# ...
